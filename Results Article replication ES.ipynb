# %%
import Theory as th
import numpy as np
from scipy.stats import t
import matplotlib.pyplot as plt
import random
import pandas as pd
import scipy.special as sc
import scipy.integrate as integrate
from scipy.stats import uniform
from scipy.stats import norm
from statsmodels.stats.power import TTestIndPower

# %% [markdown]
# # Side 23 - 5% significance level

# %%
# H_0: df = 100 - Scaled tests:
#Z_2
Z_2_scale_100_25 = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = th.scale(0.025 , 100, 't'), df = 100, dfnull = 100, Norm = False, type = 't')
Z_2_scale_100_5 =  th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = th.scale(0.05 , 100, 't'),  df = 100, dfnull = 100, Norm = False, type = 't')
Z_2_scale_100_10 = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = th.scale(0.1 , 100, 't'),   df = 100, dfnull = 100, Norm = False, type = 't')

#Z_3:
Z_3_scale_100_25 = th.Z_3(quan = 0.05, T=250, n = 100000, df=100, dfnull = 100, shift = 0, scale = th.scale(0.025 , 100, 't'))
Z_3_scale_100_5 =  th.Z_3(quan = 0.05, T=250, n = 100000, df=100, dfnull = 100, shift = 0, scale = th.scale(0.05 , 100, 't'))
Z_3_scale_100_10 = th.Z_3(quan = 0.05, T=250, n = 100000, df=100, dfnull = 100, shift = 0, scale = th.scale(0.10 , 100, 't'))

# %% [markdown]
# # Side 24 - 5% significance level

# %%
# H_0: df = 5 - Scaled tests:
#Z_2
Z_2_scale_5_25 = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = th.scale(0.025 , 5, 't'), df = 5, dfnull = 5, Norm = False, type = 't')
Z_2_scale_5_5 =  th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = th.scale(0.05 , 5, 't'),  df = 5, dfnull = 5, Norm = False, type = 't')
Z_2_scale_5_10 = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = th.scale(0.1 , 5, 't'),   df = 5, dfnull = 5, Norm = False, type = 't')

#Z_3:
Z_3_scale_5_25 = th.Z_3(quan = 0.05, T=250, n = 100000, df=5, dfnull = 5, shift = 0, scale = th.scale(0.025 , 5, 't'), Norm = False)
Z_3_scale_5_5 =  th.Z_3(quan = 0.05, T=250, n = 100000, df=5, dfnull = 5, shift = 0, scale = th.scale(0.05 , 5, 't'), Norm = False)
Z_3_scale_5_10 = th.Z_3(quan = 0.05, T=250, n = 100000, df=5, dfnull = 5, shift = 0, scale = th.scale(0.10 , 5, 't'), Norm = False)

# %% [markdown]
# # side 26 - 5% significance level

# %%
# H_0: df = 100 - Standard student t:
#Z_2
Z_2_100_100 = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 100, dfnull = 100, Norm = False, type = 't')
Z_2_100_10 =  th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 10,  dfnull = 100, Norm = False, type = 't')
Z_2_100_5 =   th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 5,   dfnull = 100, Norm = False, type = 't')
Z_2_100_3 =   th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 3,   dfnull = 100, Norm = False, type = 't')

#Z_3:
Z_3_100_100 = th.Z_3(quan = 0.05, T=250, n = 100000, df=100, dfnull = 100, shift = 0, scale = 1)
Z_3_100_10 =  th.Z_3(quan = 0.05, T=250, n = 100000, df=10,  dfnull = 100, shift = 0, scale = 1)
Z_3_100_5 =   th.Z_3(quan = 0.05, T=250, n = 100000, df=5,   dfnull = 100, shift = 0, scale = 1)
Z_3_100_3 =   th.Z_3(quan = 0.05, T=250, n = 100000, df=3,   dfnull = 100, shift = 0, scale = 1)

# %% [markdown]
# # side 27 - 5% significance level

# %%
# H_0: df = 10 - Standard student t:
#Z_2
Z_2_10_10 = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 10, dfnull = 10, Norm = False, type = 't')
Z_2_10_5 =  th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 5,  dfnull = 10, Norm = False, type = 't')
Z_2_10_3 =  th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 3,  dfnull = 10, Norm = False, type = 't')

#Z_3:
Z_3_10_10 = th.Z_3(quan = 0.05, T=250, n = 100000, df=10, dfnull = 10, shift = 0, scale = 1)
Z_3_10_5 =  th.Z_3(quan = 0.05, T=250, n = 100000, df=5,  dfnull = 10, shift = 0, scale = 1)
Z_3_10_3 =  th.Z_3(quan = 0.05, T=250, n = 100000, df=3,  dfnull = 10, shift = 0, scale = 1)

# %% [markdown]
# # side 29 - 5% significance level

# %%
# H_0: df = 100 - Normalized student t:
#Z_2
Z_2_100_100_norm = th.Z_2(quan = 0.05, sigma2 = 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 100, dfnull = 100, Norm = True, type = 't')
Z_2_100_10_norm =  th.Z_2(quan = 0.05, sigma2 = 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 10,  dfnull = 100, Norm = True, type = 't')
Z_2_100_5_norm =   th.Z_2(quan = 0.05, sigma2 = 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 5,   dfnull = 100, Norm = True, type = 't')
Z_2_100_3_norm =   th.Z_2(quan = 0.05, sigma2 = 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 3,   dfnull = 100, Norm = True, type = 't')

#Z_3:
Z_3_100_100_norm = th.Z_3(quan = 0.05, T=250, n = 100000, df=100, dfnull = 100, shift = 0, scale = 1, Norm = True)
Z_3_100_10_norm =  th.Z_3(quan = 0.05, T=250, n = 100000, df=10,  dfnull = 100, shift = 0, scale = 1, Norm = True)
Z_3_100_5_norm =   th.Z_3(quan = 0.05, T=250, n = 100000, df=5,   dfnull = 100, shift = 0, scale = 1, Norm = True)
Z_3_100_3_norm =   th.Z_3(quan = 0.05, T=250, n = 100000, df=3,   dfnull = 100, shift = 0, scale = 1, Norm = True)

# %% [markdown]
# # side 30 - 5% significance level

# %%
# H_0: df = 10 - Normalized student t:
#Z_2
Z_2_10_10_norm = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 10, dfnull = 10, Norm = True, type = 't')
Z_2_10_5_norm =  th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 5, dfnull = 10, Norm = True, type = 't')
Z_2_10_3_norm =  th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = 0 , scale  = 1, df = 3, dfnull = 10, Norm = True, type = 't')

#Z_3:
Z_3_10_10_norm = th.Z_3(quan = 0.05, T=250, n = 100000, df=10, dfnull = 10, shift = 0, scale = 1, Norm = True)
Z_3_10_5_norm =  th.Z_3(quan = 0.05, T=250, n = 100000, df=5, dfnull = 10, shift = 0, scale = 1, Norm = True)
Z_3_10_3_norm =  th.Z_3(quan = 0.05, T=250, n = 100000, df=3, dfnull = 10, shift = 0, scale = 1, Norm = True)

# %% [markdown]
# # side 32 - 5% significance level

# %%
# H_0: df = 100 - fixed VaR 2.5%:
#Z_1
Z_1_100_100_const_VaR = th.Z_1(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=100, dfnull = 100), df = 100, dfnull = 100, type = 't')
Z_1_100_10_const_VaR =  th.Z_1(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=10, dfnull = 100), df = 10, dfnull = 100, type = 't')
Z_1_100_5_const_VaR =   th.Z_1(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=5, dfnull = 100), df = 5, dfnull = 100, type = 't')
Z_1_100_3_const_VaR =   th.Z_1(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=3, dfnull = 100), df = 3, dfnull = 100, type = 't')

#Z_2
Z_2_100_100_const_VaR = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=100, dfnull = 100) , scale  = 1, df = 100, dfnull = 100, Norm = False, type = 't')
Z_2_100_10_const_VaR = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=10, dfnull = 100) , scale  = 1, df = 10, dfnull = 100, Norm = False, type = 't')
Z_2_100_5_const_VaR = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=5, dfnull = 100) , scale  = 1, df = 5, dfnull = 100, Norm = False, type = 't')
Z_2_100_3_const_VaR = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=3, dfnull = 100) , scale  = 1, df = 3, dfnull = 100, Norm = False, type = 't')

#Z_3:
Z_3_100_100_const_VaR = th.Z_3(quan = 0.05, T=250, n = 100000, df=100, dfnull = 100, shift = th.shift(0.975, df=100, dfnull = 100), scale = 1, Norm = False)
Z_3_100_10_const_VaR = th.Z_3(quan = 0.05, T=250, n = 100000, df=10, dfnull = 100, shift = th.shift(0.975, df=10, dfnull = 100), scale = 1, Norm = False)
Z_3_100_5_const_VaR = th.Z_3(quan = 0.05, T=250, n = 100000, df=5, dfnull = 100, shift = th.shift(0.975, df=5, dfnull = 100), scale = 1, Norm = False)
Z_3_100_3_const_VaR = th.Z_3(quan = 0.05, T=250, n = 100000, df=3, dfnull = 100, shift = th.shift(0.975, df=3, dfnull = 100), scale = 1, Norm = False)
# Out:
# /Users/joachimholst/Desktop/KU/Bachelor/Code/Theory.py:73: RuntimeWarning: invalid value encountered in scalar divide
#   Z_1 = q/N_t+1

# %% [markdown]
# # side 33 - 5% significance level

# %%
# H_0: df = 10 - fixed VaR 2.5%:
#Z_1
Z_1_10_10_const_VaR = th.Z_1(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=10, dfnull = 10), df = 10, dfnull = 10,  type = 't')
Z_1_10_5_const_VaR = th.Z_1(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=5, dfnull = 10),  df = 5, dfnull = 10,  type = 't')
Z_1_10_3_const_VaR = th.Z_1(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=3, dfnull = 10), df = 3, dfnull = 10, type = 't')

#Z_2
Z_2_10_10_const_VaR = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=10, dfnull = 10) , scale  = 1, df = 10, dfnull = 10, Norm = False, type = 't')
Z_2_10_5_const_VaR = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=5, dfnull = 10) , scale  = 1, df = 5, dfnull = 10, Norm = False, type = 't')
Z_2_10_3_const_VaR = th.Z_2(quan = 0.05, sigma2= 1 , mu = 0, T = 250, n = 100000, shift = th.shift(0.975, df=3, dfnull = 10) , scale  = 1, df = 3, dfnull = 10, Norm = False, type = 't')

#Z_3:
Z_3_10_10_const_VaR = th.Z_3(quan = 0.05, T=250, n = 100000, df=10, dfnull = 10, shift = th.shift(0.975, df=10, dfnull = 10), scale = 1, Norm = False)
Z_3_10_5_const_VaR = th.Z_3(quan = 0.05, T=250, n = 100000, df=5, dfnull = 10, shift = th.shift(0.975, df=5, dfnull = 10), scale = 1, Norm = False)
Z_3_10_3_const_VaR = th.Z_3(quan = 0.05, T=250, n = 100000, df=3, dfnull = 10, shift = th.shift(0.975, df=3, dfnull = 10), scale = 1, Norm = False)

# %% [markdown]
# # Power calculations, tables and plots

# %% [markdown]
# # Table 1:

# %%
#df = 5:
names = ['Power 5%', 'Power 10%']
significance_levels = [0.041, 0.106]

table1_5_Z2 = [th.Power(Z_2_scale_5_25[1], [Z_2_scale_5_5[1], Z_2_scale_5_10[1]], sl, names).compute_powers() for sl in significance_levels]
table1_5_Z3 = [th.Power(Z_3_scale_5_25[1], [Z_3_scale_5_5[1], Z_3_scale_5_10[1]], sl, names).compute_powers() for sl in significance_levels]

#Combine Z_1 and Z_2
table1_5_Z2 = pd.concat(table1_5_Z2).reset_index(drop=True)
table1_5_Z3 = pd.concat(table1_5_Z3).reset_index(drop=True)

table1_5_Z2['Source'] = 'Z2'
table1_5_Z3['Source'] = 'Z3'

table1_5 = pd.concat([table1_5_Z2, table1_5_Z3], ignore_index=True)

table1_5 = table1_5.sort_values(by=['Significance Level', 'Source'])

table1_5 = table1_5[['Significance Level', 'Source', 'Power 5%', 'Power 10%']]
table1_5['Significance Level'] *= 100

#df = 100:
names = ['Power 5%', 'Power 10%']
significance_levels = [0.040, 0.108]

table1_100_Z2 = [th.Power(Z_2_scale_100_25[1], [Z_2_scale_100_5[1], Z_2_scale_100_10[1]], sl, names).compute_powers() for sl in significance_levels]
table1_100_Z3 = [th.Power(Z_3_scale_100_25[1], [Z_3_scale_100_5[1], Z_3_scale_100_10[1]], sl, names).compute_powers() for sl in significance_levels]

#Combine Z_2 and Z_3
table1_100_Z2 = pd.concat(table1_100_Z2).reset_index(drop=True)
table1_100_Z3 = pd.concat(table1_100_Z3).reset_index(drop=True)

table1_100_Z2['Source'] = 'Z2'
table1_100_Z3['Source'] = 'Z3'

table1_100 = pd.concat([table1_100_Z2, table1_100_Z3], ignore_index=True)

table1_100 = table1_100.sort_values(by=['Significance Level', 'Source'])

table1_100 = table1_100[['Significance Level', 'Source', 'Power 5%', 'Power 10%']]
table1_100['Significance Level'] *= 100

#Final Table
table_1 = pd.concat([table1_5, table1_100], ignore_index=True)

table_1.insert(0, 'df', [5]+ ['']*3 + [100] + ['']*3)
table_1 = table_1.to_string(index=False)
print(table_1)
# Out:
#  df  Significance Level Source  Power 5%  Power 10%
#   5                 4.1     Z2   0.50955    0.98505
#                     4.1     Z3   0.25015    0.77539
#                    10.6     Z2   0.68664    0.99504
#                    10.6     Z3   0.45866    0.92154
# 100                 4.0     Z2   0.47187    0.97556
#                     4.0     Z3   0.37394    0.93149
#                    10.8     Z2   0.65316    0.99147
#                    10.8     Z3   0.57237    0.97591

# %%
names = ['α = 5%', 'α = 10%']
Figure3_Z2 = th.Power(Z_2_scale_100_25[1], [Z_2_scale_100_5[1], Z_2_scale_100_10[1]], 0.040, names).plot_cdfs()
Figure3_Z3 = th.Power(Z_3_scale_100_25[1], [Z_3_scale_100_5[1], Z_3_scale_100_10[1]], 0.040, names).plot_cdfs()

Figure4_Z2 = th.Power(Z_2_scale_5_25[1], [Z_2_scale_5_5[1], Z_2_scale_5_10[1]], 0.041, names).plot_cdfs()
Figure4_Z3 = th.Power(Z_3_scale_5_25[1], [Z_3_scale_5_5[1], Z_3_scale_5_10[1]], 0.041, names).plot_cdfs()

# %% [markdown]
# # Table 2:

# %%
#df = 10:
names = ['Power df = 5', 'Power df = 3']
significance_levels = [0.040, 0.106]

table2_10_Z2 = [th.Power(Z_2_10_10[1], [Z_2_10_5[1], Z_2_10_3[1]], sl, names).compute_powers() for sl in significance_levels]
table2_10_Z3 = [th.Power(Z_3_10_10[1], [Z_3_10_5[1], Z_3_10_3[1]], sl, names).compute_powers() for sl in significance_levels]

#Combine Z_1 and Z_2
table2_10_Z2 = pd.concat(table2_10_Z2).reset_index(drop=True)
table2_10_Z3 = pd.concat(table2_10_Z3).reset_index(drop=True)

table2_10_Z2['Source'] = 'Z2'
table2_10_Z3['Source'] = 'Z3'

table2_10 = pd.concat([table2_10_Z2, table2_10_Z3], ignore_index=True)

table2_10 = table2_10.sort_values(by=['Significance Level', 'Source'])

table2_10 = table2_10[['Significance Level', 'Source', 'Power df = 5', 'Power df = 3']]
table2_10['Significance Level'] *= 100

#df = 100:
names = ['Power df = 10', 'Power df = 3']
significance_levels = [0.041, 0.104]

table2_100_Z2 = [th.Power(Z_2_100_100[1], [Z_2_100_10[1], Z_2_100_3[1]], sl, names).compute_powers() for sl in significance_levels]
table2_100_Z3 = [th.Power(Z_3_100_100[1], [Z_3_100_10[1], Z_3_100_3[1]], sl, names).compute_powers() for sl in significance_levels]

#Combine Z_2 and Z_3
table2_100_Z2 = pd.concat(table2_100_Z2).reset_index(drop=True)
table2_100_Z3 = pd.concat(table2_100_Z3).reset_index(drop=True)

table2_100_Z2['Source'] = 'Z2'
table2_100_Z3['Source'] = 'Z3'

table2_100 = pd.concat([table2_100_Z2, table2_100_Z3], ignore_index=True)

table2_100 = table2_100.sort_values(by=['Significance Level', 'Source'])

table2_100 = table2_100[['Significance Level', 'Source', 'Power df = 10', 'Power df = 3']]
table2_100['Significance Level'] *= 100

table_2 = pd.concat([table2_10, table2_100], ignore_index=True)

table_2.insert(0, 'df', [10]+ ['']*3 + [100] + ['']*3)
table_2.insert(0,'Distribution', ['Student-t']+['']*7)
table_2 = table_2.to_string(index=False)
print(table_2)

#df = 10 normalized:
names = ['Power df = 5', 'Power df = 3']
significance_levels = [0.044, 0.112]

table2_10_Z2_norm = [th.Power(Z_2_10_10_norm[1], [Z_2_10_5_norm[1], Z_2_10_3_norm[1]], sl, names).compute_powers() for sl in significance_levels]
table2_10_Z3_norm = [th.Power(Z_3_10_10_norm[1], [Z_3_10_5_norm[1], Z_3_10_3_norm[1]], sl, names).compute_powers() for sl in significance_levels]

#Combine Z_1 and Z_2
table2_10_Z2_norm = pd.concat(table2_10_Z2_norm).reset_index(drop=True)
table2_10_Z3_norm = pd.concat(table2_10_Z3_norm).reset_index(drop=True)

table2_10_Z2_norm['Source'] = 'Z2'
table2_10_Z3_norm['Source'] = 'Z3'

table2_10_norm = pd.concat([table2_10_Z2_norm, table2_10_Z3_norm], ignore_index=True)

table2_10_norm = table2_10_norm.sort_values(by=['Significance Level', 'Source'])

table2_10_norm = table2_10_norm[['Significance Level', 'Source', 'Power df = 5', 'Power df = 3']]
table2_10_norm['Significance Level'] *= 100

#df = 100:
names = ['Power df = 10', 'Power df = 3']
significance_levels = [0.044, 0.11]

table2_100_Z2_norm = [th.Power(Z_2_100_100_norm[1], [Z_2_100_10_norm[1], Z_2_100_3_norm[1]], sl, names).compute_powers() for sl in significance_levels]
table2_100_Z3_norm = [th.Power(Z_3_100_100_norm[1], [Z_3_100_10_norm[1], Z_3_100_3_norm[1]], sl, names).compute_powers() for sl in significance_levels]

#Combine Z_2 and Z_3
table2_100_Z2_norm = pd.concat(table2_100_Z2_norm).reset_index(drop=True)
table2_100_Z3_norm = pd.concat(table2_100_Z3_norm).reset_index(drop=True)

table2_100_Z2_norm['Source'] = 'Z2'
table2_100_Z3_norm['Source'] = 'Z3'

table2_100_norm = pd.concat([table2_100_Z2_norm, table2_100_Z3_norm], ignore_index=True)

table2_100_norm= table2_100_norm.sort_values(by=['Significance Level', 'Source'])

table2_100_norm = table2_100_norm[['Significance Level', 'Source', 'Power df = 10', 'Power df = 3']]
table2_100_norm['Significance Level'] *= 100

table_2_norm = pd.concat([table2_10_norm, table2_100_norm], ignore_index=True)

table_2_norm.insert(0, 'df', [10]+ ['']*3 + [100] + ['']*3)
table_2_norm.insert(0,'Distribution', ['Normlaized t']+['']*7)
table_2_norm = table_2_norm.to_string(index=False)
print(table_2_norm)
# Out:
# Distribution  df  Significance Level Source  Power df = 5  Power df = 3  Power df = 10
#    Student-t  10                 4.0     Z2       0.42296       0.92114            NaN
#                                  4.0     Z3       0.47761       0.93858            NaN
#                                 10.6     Z2       0.59488       0.96293            NaN
#                                 10.6     Z3       0.63843       0.97127            NaN
#              100                 4.1     Z2           NaN       0.99285        0.39948
#                                  4.1     Z3           NaN       0.99771        0.53007
#                                 10.4     Z2           NaN       0.99708        0.56052
#                                 10.4     Z3           NaN       0.99901        0.66708
# Distribution  df  Significance Level Source  Power df = 5  Power df = 3  Power df = 10
# Normlaized t  10                 4.4     Z2       0.08099       0.08495            NaN
# ...

# %%
names = ['H_1 df = 10', 'H_1 df = 5', 'H_1 df = 3']
Figure6_Z2 = th.Power(Z_2_100_100[1], [Z_2_100_10[1], Z_2_100_5[1], Z_2_100_3[1]], 0.044, names).plot_cdfs()
Figure6_Z3 = th.Power(Z_3_100_100[1], [Z_3_100_10[1],Z_3_100_5[1], Z_3_100_3[1]], 0.044, names).plot_cdfs()

names = [ 'H_1 df = 5', 'H_1 df = 3']
Figure7_Z2 = th.Power(Z_2_10_10[1], [Z_2_10_5[1], Z_2_10_3[1]], 0.040, names).plot_cdfs()
Figure7_Z3 = th.Power(Z_3_10_10[1], [Z_3_10_5[1], Z_3_10_3[1]], 0.040, names).plot_cdfs()

# %%
names = ['H_1 df = 10', 'H_1 df = 5', 'H_1 df = 3']
Figure9_Z2 = th.Power(Z_2_100_100_norm[1], [Z_2_100_10_norm[1], Z_2_100_5_norm[1], Z_2_100_3_norm[1]], 0.044, names).plot_cdfs()
Figure9_Z3 = th.Power(Z_3_100_100_norm[1], [Z_3_100_10_norm[1],Z_3_100_5_norm[1], Z_3_100_3_norm[1]], 0.044, names).plot_cdfs()

names = [ 'H_1 df = 5', 'H_1 df = 3']
Figure10_Z2 = th.Power(Z_2_10_10_norm[1], [Z_2_10_5_norm[1], Z_2_10_3_norm[1]], 0.040, names).plot_cdfs()
Figure10_Z3 = th.Power(Z_3_10_10_norm[1], [Z_3_10_5_norm[1], Z_3_10_3_norm[1]], 0.040, names).plot_cdfs()

# %% [markdown]
# # Table 3:

# %%
#df = 10:
names = ['Power df = 5', 'Power df = 3']
significance_levels = [0.041, 0.107]

table3_10_Z1 = [th.Power(Z_1_10_10_const_VaR[1], [Z_1_10_5_const_VaR[1], Z_1_10_3_const_VaR[1]], sl, names).compute_powers() for sl in significance_levels]
table3_10_Z2 = [th.Power(Z_2_10_10_const_VaR[1], [Z_2_10_5_const_VaR[1], Z_2_10_3_const_VaR[1]], sl, names).compute_powers() for sl in significance_levels]
table3_10_Z3 = [th.Power(Z_3_10_10_const_VaR[1], [Z_3_10_5_const_VaR[1], Z_3_10_3_const_VaR[1]], sl, names).compute_powers() for sl in significance_levels]

#Combine Z_1 and Z_2
table3_10_Z1 = pd.concat(table3_10_Z1).reset_index(drop=True)
table3_10_Z2 = pd.concat(table3_10_Z2).reset_index(drop=True)
table3_10_Z3 = pd.concat(table3_10_Z3).reset_index(drop=True)

table3_10_Z1['Source'] = 'Z1'
table3_10_Z2['Source'] = 'Z2'
table3_10_Z3['Source'] = 'Z3'

table3_10 = pd.concat([table3_10_Z1, table3_10_Z2, table3_10_Z3], ignore_index=True)

table3_10 = table3_10.sort_values(by=['Significance Level', 'Source'])

table3_10 = table3_10[['Significance Level', 'Source', 'Power df = 5', 'Power df = 3']]
table3_10['Significance Level'] *= 100

#df = 100:
names = ['Power df = 5', 'Power df = 3']
significance_levels = [0.043, 0.109]

table3_100_Z1 = [th.Power(Z_1_100_100_const_VaR[1], [Z_1_100_10_const_VaR[1], Z_1_100_3_const_VaR[1]], sl, names).compute_powers() for sl in significance_levels]
table3_100_Z2 = [th.Power(Z_2_100_100_const_VaR[1], [Z_2_100_10_const_VaR[1], Z_2_100_3_const_VaR[1]], sl, names).compute_powers() for sl in significance_levels]
table3_100_Z3 = [th.Power(Z_3_100_100_const_VaR[1], [Z_3_100_10_const_VaR[1], Z_3_100_3_const_VaR[1]], sl, names).compute_powers() for sl in significance_levels]

#Combine Z_1 and Z_2
table3_100_Z1 = pd.concat(table3_100_Z1).reset_index(drop=True)
table3_100_Z2 = pd.concat(table3_100_Z2).reset_index(drop=True)
table3_100_Z3 = pd.concat(table3_100_Z3).reset_index(drop=True)

table3_100_Z1['Source'] = 'Z1'
table3_100_Z2['Source'] = 'Z2'
table3_100_Z3['Source'] = 'Z3'

table3_100 = pd.concat([table3_100_Z1, table3_100_Z2, table3_100_Z3], ignore_index=True)

table3_100 = table3_100.sort_values(by=['Significance Level', 'Source'])

table3_100 = table3_100[['Significance Level', 'Source', 'Power df = 5', 'Power df = 3']]
table3_100['Significance Level'] *= 100

table_3 = pd.concat([table3_10, table3_100], ignore_index=True)

table_3.insert(0, 'df', [10]+ ['']*5 + [100] + ['']*5)
table_3.insert(0,'Distribution', ['Student-t']+['']*11)
table_3 = table_3.to_string(index=False)
print(table_3)
# Out:
# Distribution  df  Significance Level Source  Power df = 5  Power df = 3
#    Student-t  10                 4.1     Z1      0.290041      0.732425
#                                  4.1     Z2      0.096250      0.278880
#                                  4.1     Z3      0.267090      0.630090
#                                 10.7     Z1      0.447891      0.826812
#                                 10.7     Z2      0.193420      0.399690
#                                 10.7     Z3      0.395360      0.714790
#              100                 4.3     Z1      0.289542      0.915829
#                                  4.3     Z2      0.079800      0.381760
#                                  4.3     Z3      0.265190      0.802840
#                                 10.9     Z1      0.443765      0.945993
#                                 10.9     Z2      0.166850      0.499000
#                                 10.9     Z3      0.379840      0.841320

# %%
names = ['H_1 df = 10', 'H_1 df = 5', 'H_1 df = 3']
Figure12_Z1 = th.Power(Z_1_100_100_const_VaR[1], [Z_1_100_10_const_VaR[1], Z_1_100_3_const_VaR[1]], 0.043, names).plot_cdfs()
Figure12_Z2 = th.Power(Z_2_100_100_const_VaR[1], [Z_2_100_10_const_VaR[1], Z_2_100_3_const_VaR[1]], 0.043, names).plot_cdfs()
Figure12_Z3 = th.Power(Z_3_100_100_const_VaR[1], [Z_3_100_10_const_VaR[1], Z_3_100_3_const_VaR[1]], 0.043, names).plot_cdfs()
names = [ 'H_1 df = 5', 'H_1 df = 3']
Figure13_Z1 = th.Power(Z_1_10_10_const_VaR[1], [Z_1_10_5_const_VaR[1], Z_1_10_3_const_VaR[1]], 0.041, names).plot_cdfs()
Figure13_Z2 = th.Power(Z_2_10_10_const_VaR[1], [Z_2_10_5_const_VaR[1], Z_2_10_3_const_VaR[1]], 0.041, names).plot_cdfs()
Figure13_Z3 = th.Power(Z_3_10_10_const_VaR[1], [Z_3_10_5_const_VaR[1], Z_3_10_3_const_VaR[1]], 0.041, names).plot_cdfs()
